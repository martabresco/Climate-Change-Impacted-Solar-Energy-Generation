# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import atlite
import numpy as np

# %%
# Open the file
dataset = xr.open_dataset('C:/Users/marta/Desktop/Thesis/Climate-Change-Impacted-Solar-Energy-Generation/rsds_3hr_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_201001010130-201412312230.nc')


# Inspect dataset to confirm variable and coordinates
print(dataset)

# Select the 'rsds' variable for the first time step
rsds = dataset['rsds']

# Extract longitude and latitude
lon = dataset['lon']
lat = dataset['lat']

# Assuming rsds is a 3D array with dimensions (time, lat, lon)
# Select the time slice number 100
rsds_slice = rsds.isel(time=100)

# Create DataArray with correct dimensions
rsds= xr.DataArray(
    rsds_slice, 
    dims=['lat', 'lon'], 
    coords={'lat': lat, 'lon': lon}
)
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:    (time: 14608, bnds: 2, lat: 96, lon: 192)
# Coordinates:
#   * time       (time) datetime64[ns] 117kB 2010-01-01T01:30:00 ... 2014-12-31...
#   * lat        (lat) float64 768B -88.57 -86.72 -84.86 ... 84.86 86.72 88.57
#   * lon        (lon) float64 2kB 0.0 1.875 3.75 5.625 ... 354.4 356.2 358.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] 234kB ...
#     lat_bnds   (lat, bnds) float64 2kB ...
#     lon_bnds   (lon, bnds) float64 3kB ...
#     rsds       (time, lat, lon) float32 1GB ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     contact:                cmip6-mpi-esm@dkrz.de
#     ...                     ...
#     title:                  MPI-ESM1-2-LR output prepared for CMIP6
#     variable_id:            rsds
#     variant_label:          r1i1p1f1
#     license:                CMIP6 model data produced by MPI-M is licensed un...
#     cmor_version:           3.5.0
#     tracking_id:            hdl:21.14100/e1e41e95-303d-429f-86bf-974b095b34a7

# %%
# Set up the plot with PlateCarree projection
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw={'projection': ccrs.PlateCarree()})

# Plot the zonal solar component, adjusting the color scale to range from 0 to 1000
solar_plot = rsds.plot(
    ax=ax,
    transform=ccrs.PlateCarree(),
    cmap='coolwarm',
    vmin=0,  # Minimum value of the color scale
    vmax=500,  # Maximum value of the color scale
    cbar_kwargs={'label': 'Zonal Irradiance (W/m^2)'}
)

# Add map features for context
ax.coastlines(resolution='10m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# Set map extent based on data coordinates
ax.set_extent([lon.min(), lon.max(), lat.min(), lat.max()], crs=ccrs.PlateCarree())

# Title and labels
plt.title('Zonal Irradiance Component (rsds) with Geographic Overlay [ESGF Data]')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()

# %%
# --- Step 1: Define the European Region with atlite Cutout ---
cutout = atlite.Cutout(
    path='europe_solar',
    module='era5',
    x=slice(-10, 20),  # Longitude: West Portugal to East Italy
    y=slice(35, 70),   # Latitude: South Spain to North Norway
    time='2011-01-01'  # Example time (matches dataset)
)

# Prepare the cutout (atlite requires this for analysis)
cutout.prepare()
print(cutout.data)
# Out:
# <xarray.Dataset> Size: 26MB
# Dimensions:               (x: 121, y: 141, time: 24)
# Coordinates:
#   * x                     (x) float64 968B -10.0 -9.75 -9.5 ... 19.5 19.75 20.0
#   * y                     (y) float64 1kB 35.0 35.25 35.5 ... 69.5 69.75 70.0
#   * time                  (time) datetime64[ns] 192B 2011-01-01 ... 2011-01-0...
#     lon                   (x) float64 968B dask.array<chunksize=(121,), meta=np.ndarray>
#     lat                   (y) float64 1kB dask.array<chunksize=(141,), meta=np.ndarray>
# Data variables: (12/15)
#     height                (y, x) float32 68kB dask.array<chunksize=(141, 121), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     wnd_shear_exp         (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     roughness             (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     ...                    ...
#     solar_altitude        (time, y, x) float64 3MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 3MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     temperature           (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     runoff                (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
# Attributes:
#     module:                  era5
#     prepared_features:       ['wind', 'height', 'influx', 'runoff', 'temperat...
#     chunksize_time:          100
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-01-23T10:40 GRIB to CDM+CF via cfgrib-0.9.1...
# c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\atlite\cutout.py:155: UserWarning: Arguments module, x, y, time are ignored, since cutout is already built.
#   warn(

# %%
print(cutout.data.data_vars)
# Out:
# Data variables:
#     height                (y, x) float32 68kB dask.array<chunksize=(141, 121), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     wnd_shear_exp         (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     roughness             (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     influx_direct         (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     influx_diffuse        (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     albedo                (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     solar_altitude        (time, y, x) float64 3MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 3MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     temperature           (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>
#     runoff                (time, y, x) float32 2MB dask.array<chunksize=(24, 141, 121), meta=np.ndarray>

# %%
direct_irradiance=cutout.data.influx_direct
diffuse_irradiance=cutout.data.influx_diffuse
solar_irradiance= direct_irradiance+diffuse_irradiance
time=cutout.data.time
specific_time = "2011-01-01T00:00:00.000000000"
#rsds_at_time = rsds.sel(time=specific_time)

print(solar_irradiance)
print(time)
# Create the plot
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})

# Select solar irradiance for 12:00 PM (noon)
solar_irradiance.isel(time=specific_time).plot(
    ax=ax,
    transform=ccrs.PlateCarree(),
    cmap='Reds',  # Red color scale for solar irradiance
    cbar_kwargs={'label': 'Solar irradiance (W/m^2)'}
)

# Add map features for context
ax.coastlines(resolution='10m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# Set extent to Europe
ax.set_extent([-10, 20, 35, 70], crs=ccrs.PlateCarree())

# Add title and labels
plt.title('Solar Irradiance over Europe [Atlite Data]')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()
# Out:
# <xarray.DataArray (time: 24, y: 141, x: 121)> Size: 2MB
# dask.array<add, shape=(24, 141, 121), dtype=float32, chunksize=(24, 141, 121), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 968B -10.0 -9.75 -9.5 -9.25 ... 19.25 19.5 19.75 20.0
#   * y        (y) float64 1kB 35.0 35.25 35.5 35.75 ... 69.25 69.5 69.75 70.0
#   * time     (time) datetime64[ns] 192B 2011-01-01 ... 2011-01-01T23:00:00
#     lon      (x) float64 968B dask.array<chunksize=(121,), meta=np.ndarray>
#     lat      (y) float64 1kB dask.array<chunksize=(141,), meta=np.ndarray>
# <xarray.DataArray 'time' (time: 24)> Size: 192B
# array(['2011-01-01T00:00:00.000000000', '2011-01-01T01:00:00.000000000',
#        '2011-01-01T02:00:00.000000000', '2011-01-01T03:00:00.000000000',
#        '2011-01-01T04:00:00.000000000', '2011-01-01T05:00:00.000000000',
#        '2011-01-01T06:00:00.000000000', '2011-01-01T07:00:00.000000000',
#        '2011-01-01T08:00:00.000000000', '2011-01-01T09:00:00.000000000',
#        '2011-01-01T10:00:00.000000000', '2011-01-01T11:00:00.000000000',
#        '2011-01-01T12:00:00.000000000', '2011-01-01T13:00:00.000000000',
#        '2011-01-01T14:00:00.000000000', '2011-01-01T15:00:00.000000000',
#        '2011-01-01T16:00:00.000000000', '2011-01-01T17:00:00.000000000',
#        '2011-01-01T18:00:00.000000000', '2011-01-01T19:00:00.000000000',
#        '2011-01-01T20:00:00.000000000', '2011-01-01T21:00:00.000000000',
#        '2011-01-01T22:00:00.000000000', '2011-01-01T23:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 192B 2011-01-01 ... 2011-01-01T23:00:00
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 14
#      11 fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
#      13 # Select solar irradiance for 12:00 PM (noon)
# ---> 14 solar_irradiance.isel(time=specific_time).plot(
#      15     ax=ax,
#      16     transform=ccrs.PlateCarree(),
#      17     cmap='Reds',  # Red color scale for solar irradiance
#      18     cbar_kwargs={'label': 'Solar irradiance (W/m^2)'}
#      19 )
#      21 # Add map features for context
#      22 ax.coastlines(resolution='10m', linewidth=1)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\dataarray.py:1485, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1482 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    1484 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1485     ds = self._to_temp_dataset()._isel_fancy(
#    1486         indexers, drop=drop, missing_dims=missing_dims
#    1487     )
#    1488     return self._from_temp_dataset(ds)
#    1490 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1491 # lists, or zero or one-dimensional np.ndarray's
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\dataset.py:3000, in Dataset._isel_fancy(self, indexers, drop, missing_dims)
#    2996 var_indexers = {
#    2997     k: v for k, v in valid_indexers.items() if k in var.dims
#    2998 }
#    2999 if var_indexers:
# -> 3000     new_var = var.isel(indexers=var_indexers)
#    3001     # drop scalar coordinates
#    3002     # https://github.com/pydata/xarray/issues/6554
#    3003     if name in self.coords and drop and new_var.ndim == 0:
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\variable.py:1018, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1015 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1017 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1018 return self[key]
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\variable.py:785, in Variable.__getitem__(self, key)
#     782 dims, indexer, new_order = self._broadcast_indexes(key)
#     783 indexable = as_indexable(self._data)
# --> 785 data = indexing.apply_indexer(indexable, indexer)
#     787 if new_order:
#     788     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\indexing.py:1002, in apply_indexer(indexable, indexer)
#    1000     return indexable.oindex[indexer]
#    1001 else:
# -> 1002     return indexable[indexer]
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\indexing.py:1758, in PandasIndexingAdapter.__getitem__(self, indexer)
#    1755     indexable = NumpyIndexingAdapter(np.asarray(self))
#    1756     return indexable[indexer]
# -> 1758 result = self.array[key]
#    1760 return self._handle_result(result)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexes\base.py:5320, in Index.__getitem__(self, key)
#    5317 if is_integer(key) or is_float(key):
#    5318     # GH#44051 exclude bool, which would return a 2d ndarray
#    5319     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5320     return getitem(key)
#    5322 if isinstance(key, slice):
#    5323     # This case is separated from the conditional above to avoid
#    5324     # pessimization com.is_bool_indexer and ndim checks.
#    5325     result = getitem(key)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\pandas\core\arrays\datetimelike.py:358, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     350 """
#     351 This getitem defers to the underlying array, which by-definition can
#     352 only handle list-likes, slices, and integer scalars
#     353 """
#     354 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     355 # but skip evaluating the Union at runtime for performance
#     356 # (see https://github.com/pandas-dev/pandas/pull/44624)
#     357 result = cast(
# --> 358     "Union[DatetimeLikeArrayT, DTScalarOrNaT]", super().__getitem__(key)
#     359 )
#     360 if lib.is_scalar(result):
#     361     return result
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\pandas\core\arrays\_mixins.py:289, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     283 def __getitem__(
#     284     self: NDArrayBackedExtensionArrayT,
#     285     key: PositionalIndexer2D,
#     286 ) -> NDArrayBackedExtensionArrayT | Any:
#     287     if lib.is_integer(key):
#     288         # fast-path
# --> 289         result = self._ndarray[key]
#     290         if self.ndim == 1:
#     291             return self._box_func(result)
#
# IndexError: index 1293840000000000000 is out of bounds for axis 0 with size 24

# %%
# Extract rsds (solar irradiance) and keep the time dimension intact
rsds = dataset['rsds']  # Ensure 'rsds' has the 'time' dimension

# Select solar irradiance for the specific time
specific_time = "2010-05-01T10:30:00"
rsds_at_time = rsds.sel(time=specific_time)

# Print the selected data values
print(f"Solar irradiance values at {specific_time}:")
print(rsds_at_time.values)

# Create the plot
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})

# Plot the solar irradiance at the selected time
rsds_at_time.plot(
    ax=ax,
    transform=ccrs.PlateCarree(),
    cmap='Reds',  # Red color scale for solar irradiance
    cbar_kwargs={'label': 'Solar irradiance (W/m^2)'}
)

# Add map features for context
ax.coastlines(resolution='10m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# Set extent to Europe
ax.set_extent([-10, 20, 35, 70], crs=ccrs.PlateCarree())

# Add title and labels
plt.title(f'Solar Irradiance over Europe at {specific_time}')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()
# Out:
# Solar irradiance values at 2010-05-01T10:30:00:
# [[7.3242188e-04 7.3242188e-04 7.3242188e-04 ... 7.3242188e-04
#   7.3242188e-04 7.3242188e-04]
#  [7.3242188e-04 7.3242188e-04 7.3242188e-04 ... 7.3242188e-04
#   7.3242188e-04 7.3242188e-04]
#  [7.3242188e-04 7.3242188e-04 7.3242188e-04 ... 7.3242188e-04
#   7.3242188e-04 7.3242188e-04]
#  ...
#  [3.1171948e+02 3.2431323e+02 3.2520386e+02 ... 3.3417261e+02
#   3.3461011e+02 3.0846948e+02]
#  [3.1503198e+02 3.1420386e+02 3.2134448e+02 ... 2.9096948e+02
#   3.0054761e+02 3.1345386e+02]
#  [2.1796948e+02 2.1518823e+02 2.1798511e+02 ... 2.2612573e+02
#   2.3451636e+02 2.1587573e+02]]

# %%
rsds = dataset['rsds']  # Ensure 'rsds' has the 'time' dimension

# %%
# Interpolate irradiance onto the Atlite cutout grid because ESFG has dif coordinates than atlite
#force arrays to the same lenghts
irradiance_on_cutout = rsds_at_time.interp(
    lon=cutout.grid.x,
    lat=cutout.grid.y,
    method='linear'
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Interpolate irradiance onto the Atlite cutout grid because ESFG has dif coordinates than atlite
#       2 #force arrays to the same lenghts
# ----> 3 irradiance_on_cutout = rsds_at_time.interp(
#       4     lon=cutout.grid.x,
#       5     lat=cutout.grid.y,
#       6     method='linear'
#       7 )
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\dataarray.py:2307, in DataArray.interp(self, coords, method, assume_sorted, kwargs, **coords_kwargs)
#    2303 if self.dtype.kind not in "uifc":
#    2304     raise TypeError(
#    2305         f"interp only works for a numeric type array. Given {self.dtype}."
#    2306     )
# -> 2307 ds = self._to_temp_dataset().interp(
#    2308     coords,
#    2309     method=method,
#    2310     kwargs=kwargs,
#    2311     assume_sorted=assume_sorted,
#    2312     **coords_kwargs,
#    2313 )
#    2314 return self._from_temp_dataset(ds)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\dataset.py:4003, in Dataset.interp(self, coords, method, assume_sorted, kwargs, method_non_numeric, **coords_kwargs)
#    4000 if dtype_kind in "uifc":
#    4001     # For normal number types do the interpolation:
#    4002     var_indexers = {k: v for k, v in use_indexers.items() if k in var.dims}
# -> 4003     variables[name] = missing.interp(var, var_indexers, method, **kwargs)
#    4004 elif dtype_kind in "ObU" and (use_indexers.keys() & var.dims):
#    4005     # For types that we do not understand do stepwise
#    4006     # interpolation to avoid modifying the elements.
#    (...)
#    4009     # this loop there might be some duplicate code that slows it
#    4010     # down, therefore collect these signals and run it later:
#    4011     reindex = True
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\missing.py:632, in interp(var, indexes_coords, method, **kwargs)
#     630 original_dims = broadcast_dims + dims
#     631 new_dims = broadcast_dims + list(destination[0].dims)
# --> 632 interped = interp_func(
#     633     var.transpose(*original_dims).data, x, destination, method, kwargs
#     634 )
#     636 result = Variable(new_dims, interped, attrs=var.attrs, fastpath=True)
#     638 # dimension of the output array
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\missing.py:749, in interp_func(var, x, new_x, method, kwargs)
#     733     meta = var._meta
#     735     return chunkmanager.blockwise(
#     736         _chunked_aware_interpnd,
#     737         out_ind,
#    (...)
#     746         align_arrays=False,
#     747     )
# --> 749 return _interpnd(var, x, new_x, func, kwargs)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\missing.py:767, in _interpnd(var, x, new_x, func, kwargs)
#     764 x, new_x = _floatize_x(x, new_x)
#     766 if len(x) == 1:
# --> 767     return _interp1d(var, x, new_x, func, kwargs)
#     769 # move the interpolation axes to the start position
#     770 var = var.transpose(range(-len(x), var.ndim - len(x)))
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\missing.py:755, in _interp1d(var, x, new_x, func, kwargs)
#     752 def _interp1d(var, x, new_x, func, kwargs):
#     753     # x, new_x are tuples of size 1.
#     754     x, new_x = x[0], new_x[0]
# --> 755     rslt = func(x, var, assume_sorted=True, **kwargs)(np.ravel(new_x))
#     756     if new_x.ndim > 1:
#     757         return reshape(rslt, (var.shape[:-1] + new_x.shape))
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\core\missing.py:72, in BaseInterpolator.__call__(self, x)
#      71 def __call__(self, x):
# ---> 72     return self.f(x, **self.call_kwargs)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\scipy\interpolate\_polyint.py:80, in _Interpolator1D.__call__(self, x)
#      59 """
#      60 Evaluate the interpolant
#      61
#    (...)
#      77
#      78 """
#      79 x, x_shape = self._prepare_x(x)
# ---> 80 y = self._evaluate(x)
#      81 return self._finish_y(y, x_shape)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\scipy\interpolate\_interpolate.py:750, in interp1d._evaluate(self, x_new)
#     745 def _evaluate(self, x_new):
#     746     # 1. Handle values in x_new that are outside of x. Throw error,
#     747     #    or return a list of mask array indicating the outofbounds values.
#     748     #    The behavior is set by the bounds_error variable.
#     749     x_new = asarray(x_new)
# --> 750     y_new = self._call(self, x_new)
#     751     if not self._extrapolate:
#     752         below_bounds, above_bounds = self._check_bounds(x_new)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\scipy\interpolate\_interpolate.py:694, in interp1d._call_linear(self, x_new)
#     692 x_hi = self.x[hi]
#     693 y_lo = self._y[lo]
# --> 694 y_hi = self._y[hi]
#     696 # Note that the following two expressions rely on the specifics of the
#     697 # broadcasting semantics.
#     698 slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#
# MemoryError: Unable to allocate 21.4 GiB for an array with shape (17061, 335984) and data type float32

# %%
# --- Step 1: Ensure Irradiance Data is Sorted ---
irradiance_on_cutout = irradiance_on_cutout.sortby('lat').sortby('lon')

# --- Step 2: Plot the Interpolated Irradiance ---
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})

# Plot the sorted irradiance data
irradiance_on_cutout.plot(
    ax=ax,
    transform=ccrs.PlateCarree(),
    cmap='viridis',
    cbar_kwargs={'label': 'Irradiance (W/M^2)'}
)

# --- Step 3: Add Geographic Features ---
ax.coastlines(resolution='10m', linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='white')

# --- Step 4: Set Map Extent to the Cutout Region ---
bounds = cutout.grid.total_bounds
ax.set_extent([bounds[0], bounds[2], bounds[1], bounds[3]], crs=ccrs.PlateCarree())

# --- Step 5: Final Plot Settings ---
plt.title('Interpolated ESGF Irradiance over Atlite Cutout')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       5 fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
#       7 # Plot the sorted irradiance data
# ----> 8 irradiance_on_cutout.plot(
#       9     ax=ax,
#      10     transform=ccrs.PlateCarree(),
#      11     cmap='viridis',
#      12     cbar_kwargs={'label': 'Irradiance (W/M^2)'}
#      13 )
#      15 # --- Step 3: Add Geographic Features ---
#      16 ax.coastlines(resolution='10m', linewidth=1)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\plot\accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\plot\dataarray_plot.py:309, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     305     plotfunc = hist
#     307 kwargs["ax"] = ax
# --> 309 return plotfunc(darray, **kwargs)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\plot\dataarray_plot.py:1601, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1597     raise ValueError("plt.imshow's `aspect` kwarg is not available in xarray")
#    1599 ax = get_axis(figsize, size, aspect, ax, **subplot_kws)
# -> 1601 primitive = plotfunc(
#    1602     xplt,
#    1603     yplt,
#    1604     zval,
#    1605     ax=ax,
#    1606     cmap=cmap_params["cmap"],
#    1607     vmin=cmap_params["vmin"],
#    1608     vmax=cmap_params["vmax"],
#    1609     norm=cmap_params["norm"],
#    1610     **kwargs,
#    1611 )
#    1613 # Label the plot with metadata
#    1614 if add_labels:
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\xarray\plot\dataarray_plot.py:2310, in pcolormesh(x, y, z, ax, xscale, yscale, infer_intervals, **kwargs)
#    2307         y = _infer_interval_breaks(y, axis=0, scale=yscale)
#    2309 ax.grid(False)
# -> 2310 primitive = ax.pcolormesh(x, y, z, **kwargs)
#    2312 # by default, pcolormesh picks "round" values for bounds
#    2313 # this results in ugly looking plots with lots of surrounding whitespace
#    2314 if not hasattr(ax, "projection") and x.ndim == 1 and y.ndim == 1:
#    2315     # not a cartopy geoaxis
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\cartopy\mpl\geoaxes.py:306, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     301     raise ValueError(f'Invalid transform: Spherical {func.__name__} '
#     302                      'is not supported - consider using '
#     303                      'PlateCarree/RotatedPole.')
#     305 kwargs['transform'] = transform
# --> 306 return func(self, *args, **kwargs)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\cartopy\mpl\geoaxes.py:1777, in GeoAxes.pcolormesh(self, *args, **kwargs)
#    1774 # Add in an argument checker to handle Matplotlib's potential
#    1775 # interpolation when coordinate wraps are involved
#    1776 args, kwargs = self._wrap_args(*args, **kwargs)
# -> 1777 result = super().pcolormesh(*args, **kwargs)
#    1778 # Wrap the quadrilaterals if necessary
#    1779 result = self._wrap_quadmesh(result, **kwargs)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\matplotlib\axes\_axes.py:6491, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, colorizer, shading, antialiased, *args, **kwargs)
#    6488 shading = shading.lower()
#    6489 kwargs.setdefault('edgecolors', 'none')
# -> 6491 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6492                                     shading=shading, kwargs=kwargs)
#    6493 coords = np.stack([X, Y], axis=-1)
#    6495 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\matplotlib\axes\_axes.py:6071, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    6068             Y = _interp_grid(Y.T, require_monotonicity=True).T
#    6069         shading = 'flat'
# -> 6071 C = cbook.safe_masked_invalid(C, copy=True)
#    6072 return X, Y, C, shading
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\matplotlib\cbook.py:691, in safe_masked_invalid(x, copy)
#     689     x = x.byteswap(inplace=copy).view(x.dtype.newbyteorder('N'))
#     690 try:
# --> 691     xm = np.ma.masked_where(~(np.isfinite(x)), x, copy=False)
#     692 except TypeError:
#     693     return x
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\numpy\ma\core.py:1942, in masked_where(condition, a, copy)
#    1940 result = a.view(cls)
#    1941 # Assign to *.mask so that structured masks are handled correctly.
# -> 1942 result.mask = _shrink_mask(cond)
#    1943 # There is no view of a boolean so when 'a' is a MaskedArray with nomask
#    1944 # the update to the result's mask has no effect.
#    1945 if not copy and hasattr(a, '_mask') and getmask(a) is nomask:
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\numpy\ma\core.py:3516, in MaskedArray.mask(self, value)
#    3514 @mask.setter
#    3515 def mask(self, value):
# -> 3516     self.__setmask__(value)
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\numpy\ma\core.py:3499, in MaskedArray.__setmask__(self, mask, copy)
#    3497 # Reshape if needed
#    3498 if current_mask.shape:
# -> 3499     current_mask.shape = self.shape
#    3500 return
#
# File c:\Users\marta\anaconda3\envs\myenv\Lib\site-packages\numpy\ma\core.py:3423, in MaskedArray.shape(self)
#    3421 @property
#    3422 def shape(self):
# -> 3423     return super().shape
#
# KeyboardInterrupt:
