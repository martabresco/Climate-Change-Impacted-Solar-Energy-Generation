# %%
import atlite
import logging
from matplotlib import pyplot as plt
import xarray as xr

logging.basicConfig(level=logging.INFO)

# %%
filename="/groups/EXTREMES/cutouts/europe-2000-era5.nc"
ds=xr.open_dataset(filename)
ds
# Out:
# <xarray.Dataset> Size: 17GB
# Dimensions:           (x: 189, y: 157, time: 8784)
# Coordinates:
#   * x                 (x) float64 2kB -12.0 -11.75 -11.5 ... 34.5 34.75 35.0
#   * y                 (y) float64 1kB 33.0 33.25 33.5 33.75 ... 71.5 71.75 72.0
#   * time              (time) datetime64[ns] 70kB 2000-01-01 ... 2000-12-31T23...
#     lon               (x) float64 2kB ...
#     lat               (y) float64 1kB ...
# Data variables: (12/13)
#     height            (y, x) float32 119kB ...
#     wnd100m           (time, y, x) float32 1GB ...
#     wnd_azimuth       (time, y, x) float32 1GB ...
#     roughness         (time, y, x) float32 1GB ...
#     influx_toa        (time, y, x) float32 1GB ...
#     influx_direct     (time, y, x) float32 1GB ...
#     ...                ...
#     albedo            (time, y, x) float32 1GB ...
#     solar_altitude    (time, y, x) float64 2GB ...
#     solar_azimuth     (time, y, x) float64 2GB ...
#     temperature       (time, y, x) float64 2GB ...
#     soil temperature  (time, y, x) float64 2GB ...
#     runoff            (time, y, x) float32 1GB ...
# Attributes:
#     module:             era5
#     prepared_features:  ['temperature', 'height', 'runoff', 'wind', 'influx']
#     chunksize_time:     100
#     Conventions:        CF-1.6
#     history:            2023-02-17 13:27:48 GMT by grib_to_netcdf-2.25.1: /op...

# %%
# Define the geographic extent
x_range = slice(-12, 35)
y_range = slice(33, 72)

# Hard-coded start and end dates for January 2008
start_date = "1990-01-01"
end_date = "1990-12-31"

cutout_path = "/groups/FutureWind/SFCRAD/CanESM5/historical/r1i1p2f1/rsds_rsdsdiff_tas_1990.nc"
ds=xr.open_dataset(cutout_path)
ds.attrs['module'] = 'era5'
print(ds)

#%%

# Load the cutout with the required parameters
cutout = atlite.Cutout(
    path="cutouts",
    module='era5',
    x=ds.lon,
    y=ds.lat,
    time=ds.time,
    data=ds
)
# Out:
# <xarray.Dataset> Size: 20MB
# Dimensions:   (time: 2920, lat: 20, lon: 28)
# Coordinates:
#   * lon       (lon) float32 112B -28.12 -25.31 -22.5 -19.69 ... 42.19 45.0 47.81
#   * lat       (lat) float32 80B 20.93 23.72 26.51 29.3 ... 68.37 71.16 73.95
#   * time      (time) object 23kB 1990-01-01 01:30:00 ... 1990-12-31 22:30:00
# Data variables:
#     rsds      (time, lat, lon) float32 7MB ...
#     rsdsdiff  (time, lat, lon) float32 7MB ...
#     tas       (time, lat, lon) float32 7MB ...
# Attributes:
#     data_source:    Processed data from CMIP6 runs
#     experiment:     historical
#     source:         CanESM5
#     variant_label:  r1i1p2f1
#     data_written:   12/03/2025 14:04
#     module:         era5

# %%
cutout = atlite.Cutout(path=cutout_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cutout = atlite.Cutout(path=cutout_path)
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/cutout.py:194, in Cutout.__init__(self, path, **cutoutparams)
#     192 # Check compatibility of CRS
#     193 modules = atleast_1d(data.attrs.get("module"))
# --> 194 crs = set(CRS(datamodules[m].crs) for m in modules)
#     195 assert len(crs) == 1, f"CRS of {module} not compatible"
#     197 self.path = path
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/cutout.py:194, in <genexpr>(.0)
#     192 # Check compatibility of CRS
#     193 modules = atleast_1d(data.attrs.get("module"))
# --> 194 crs = set(CRS(datamodules[m].crs) for m in modules)
#     195 assert len(crs) == 1, f"CRS of {module} not compatible"
#     197 self.path = path
#
# KeyError: None

# %%
cutout.prepare()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cutout.prepare()
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/data.py:115, in maybe_remove_tmpdir.<locals>.wrapper(*args, **kwargs)
#     113 kwargs["tmpdir"] = mkdtemp()
#     114 try:
# --> 115     res = func(*args, **kwargs)
#     116 finally:
#     117     rmtree(kwargs["tmpdir"])
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/data.py:187, in cutout_prepare(cutout, features, tmpdir, overwrite, compression, show_progress, dask_kwargs, monthly_requests, concurrent_requests)
#     184 if dask_kwargs is None:
#     185     dask_kwargs = {}
# --> 187 if cutout.prepared and not overwrite:
#     188     logger.info("Cutout already prepared.")
#     189     return cutout
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/cutout.py:328, in Cutout.prepared(self)
#     323 @property
#     324 def prepared(self):
#     325     """
#     326     Boolean indicating whether all available features are prepared.
#     327     """
# --> 328     return self.prepared_features.sort_index().equals(
#     329         self.available_features.sort_index()
#     330     )
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/cutout.py:338, in Cutout.prepared_features(self)
#     332 @property
#     333 def prepared_features(self):
#     334     """
#     335     Get the list of prepared features in the cutout.
#     336     """
#     337     index = [
# --> 338         (self.data[v].attrs["module"], self.data[v].attrs["feature"])
#     339         for v in self.data
#     340     ]
#     341     index = pd.MultiIndex.from_tuples(index, names=["module", "feature"])
#     342     return pd.Series(list(self.data), index, dtype=object)
#
# KeyError: 'module'
