# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import atlite
import numpy as np
import logging 
logging.basicConfig(level=logging.INFO)
import xesmf as xe
# Out:
# /home/s233224/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %%
file ="/work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/bias_factor_era5_ACCESS-CM2_influx_diffuse.nc"
ds=xr.open_dataset(file)
ds.bias_factor.values
# Out:
# array([[0.87114656, 0.8483368 , 0.86187905, 0.81849504, 0.8161863 ,
#         0.8318978 , 0.8057017 , 0.82955605, 0.83928025, 0.8587535 ,
#         0.85965204, 0.8215089 , 0.81348586, 0.8077258 , 0.7912488 ,
#         0.7914294 , 0.7954655 , 0.7832421 , 0.78406096, 0.8026443 ,
#         0.819166  , 0.8278976 , 0.8478708 , 0.85967326, 0.5618999 ],
#        [1.2322901 , 1.2157578 , 1.1986002 , 1.1392419 , 1.0967125 ,
#         1.072257  , 1.0846262 , 1.0709753 , 1.1099638 , 1.1390451 ,
#         1.1383824 , 1.1174484 , 1.1605641 , 1.142081  , 1.0816754 ,
#         1.0954119 , 1.1080126 , 1.1180948 , 1.0915675 , 1.0947583 ,
#         1.1276321 , 1.1402371 , 1.17306   , 1.187104  , 0.7563684 ],
#        [1.2419989 , 1.2367752 , 1.2195088 , 1.2220538 , 1.2002916 ,
#         1.232006  , 1.1276588 , 1.0957932 , 1.0999488 , 1.1223848 ,
#         1.1326268 , 1.1276534 , 1.1683123 , 1.1361785 , 1.0613568 ,
#         1.0972598 , 1.1058161 , 1.1271693 , 1.1201574 , 1.1344906 ,
# ...

# %%
import os
def calculate_mean_nc(filename):
    try:
        # Open the .nc file using xarray
        ds = xr.open_dataset(filename)
        if "bias_factor" in ds:
            # Calculate the mean of the bias_factor variable
            mean_value = ds.bias_factor.mean().item()  # Convert to a Python float
            return mean_value
        else:
            return "bias_factor variable not found"
    except FileNotFoundError:
        return "File not found"
    except Exception as e:
        return f"Error processing file: {e}"

def process_folder_nc(folder_path):
    if not os.path.isdir(folder_path):
        print("Invalid folder path.")
        return

    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and file_name.endswith(".nc"):  # Ensure it's a .nc file
            logging.info(f"Processing file: {file_path}")
            mean_value = calculate_mean_nc(file_path)
            print(f"{file_name}: {mean_value}")

# Example usage
folder = "/work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/"
process_folder_nc(folder)
# Out:
# INFO:root:Processing file: /work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/bias_factor_era5_ACCESS-CM2_influx_diffuse.nc
# INFO:root:Processing file: /work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/bias_factor_era5_HadGEM3-GC31-MM_influx_diffuse.nc
# INFO:root:Processing file: /work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/bias_factor_era5_CMCC-ESM2_temperature.nc
# INFO:root:Processing file: /work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/bias_factor_era5_CMCC-CM2-SR5_influx_direct.nc
# INFO:root:Processing file: /work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/bias_factor_era5_ACCESS-CM2_temperature.nc
# INFO:root:Processing file: /work/users/s233224/Climate-Change-Impacted-Solar-Energy-Generation/bias_factors/bias_factor_era5_MRI-ESM2-0_temperature.nc
# ...
